# %% [markdown]
# ## Introduccion a las bases de Dask

# %%
# Funciones basicas
import dask
from time import sleep

def inc(x):
    sleep(1)
    return x + 1

def add(x, y):
    sleep(1)
    return x + y

# %%
# %%time

x = inc(2)
y = inc (3)
z = add(x,y)
# Out:
# CPU times: total: 0 ns
# Wall time: 996 µs

# %%
from dask import delayed

@delayed
def inc(x):
    sleep(1)
    return x + 1

@delayed
def add(x, y):
    sleep(1)
    return x + y

# %%
# %%time

x = delayed(inc)(2)
y = delayed(inc)(3)
z = delayed(add)(x,y)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# z.visualize()
# Similar a los diagramas de tensorflow

# %%
data = [ x for x in range(10000) if x % 2 == 0]

# %%
# %%time

res = []
for d in data:
    y = inc(x)
    res.append(y)

total = sum(res)
# Out:
# CPU times: total: 3.47 s
# Wall time: 7.36 s

# %%
# %%time

res = []
for d in data:
    y = delayed(inc)(x)
    res.append(y)

total = delayed(sum)(res)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 127 ms

# %% [markdown]
# **`Tree summation`**

# %% [markdown]
# ![image.png](attachment:image.png)
